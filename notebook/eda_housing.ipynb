# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df = pd.read_csv("D:/internship/task2/dataset/cleaned_housing_data.csv")

df.head()
# Out:
#      country  iso  year  house_price_index  personal_disposable_income  \
# 0  Australia  AUS  1975               2.83                        7.19
# 1  Australia  AUS  1976               3.19                        8.11
# 2  Australia  AUS  1977               3.48                        8.91
# 3  Australia  AUS  1978               3.75                        9.85
# 4  Australia  AUS  1979               4.20                       10.80
#
#    real_house_price_index  real_personal_disposable_income  \
# 0                   21.89                            55.72
# 1                   21.65                            55.04
# 2                   21.43                            54.88
# 3                   21.28                            55.91
# 4                   21.75                            55.94
#
#    affordability_proxy  country_encoded  iso_encoded
# 0                39.29                0            0
# 1                39.34                0            0
# 2                39.05                0            0
# 3                38.06                0            0
# 4                38.88                0            0

# %%
df.shape
# Out:
# (1237, 10)

# %%
df.columns
# Out:
# Index(['country', 'iso', 'year', 'house_price_index',
#        'personal_disposable_income', 'real_house_price_index',
#        'real_personal_disposable_income', 'affordability_proxy',
#        'country_encoded', 'iso_encoded'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1237 entries, 0 to 1236
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country                          1237 non-null   object
#  1   iso                              1237 non-null   object
#  2   year                             1237 non-null   int64
#  3   house_price_index                1237 non-null   float64
#  4   personal_disposable_income       1237 non-null   float64
#  5   real_house_price_index           1237 non-null   float64
#  6   real_personal_disposable_income  1237 non-null   float64
#  7   affordability_proxy              1237 non-null   float64
#  8   country_encoded                  1237 non-null   int64
#  9   iso_encoded                      1237 non-null   int64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 96.8+ KB

# %%
df.isnull().sum()
# Out:
# country                            0
# iso                                0
# year                               0
# house_price_index                  0
# personal_disposable_income         0
# real_house_price_index             0
# real_personal_disposable_income    0
# affordability_proxy                0
# country_encoded                    0
# iso_encoded                        0
# dtype: int64

# %%
df.describe() #Summary statistics such as mean, standard deviation, minimum and maximum values were generated.
# Out:
#               year  house_price_index  personal_disposable_income  \
# count  1237.000000        1237.000000                 1237.000000
# mean   2001.037995          45.518076                   47.471431
# std      14.565698          31.756527                   28.061126
# min    1975.000000           0.000000                    0.000000
# 25%    1989.000000          17.080000                   24.260000
# 50%    2002.000000          42.350000                   46.250000
# 75%    2014.000000          69.670000                   69.750000
# max    2025.000000         118.820000                  106.490000
#
#        real_house_price_index  real_personal_disposable_income  \
# count             1237.000000                      1237.000000
# mean                69.755255                        74.588941
# std                 28.080611                        17.854668
# min                 16.140000                        26.280000
# 25%                 47.390000                        60.010000
# 50%                 68.500000                        75.690000
# 75%                 94.100000                        89.730000
# max                146.070000                       107.730000
#
#        affordability_proxy  country_encoded  iso_encoded
# count          1237.000000      1237.000000  1237.000000
# mean             91.305659        12.539208    12.566694
# std              24.465296         7.584121     7.657079
# min              37.300000         0.000000     0.000000
# 25%              74.080000         6.000000     6.000000
# 50%              93.110000        13.000000    12.000000
# 75%             105.810000        19.000000    19.000000
# max             158.640000        25.000000    25.000000

# %%
df.median(numeric_only=True) #Median values were calculated to understand the central tendency of numerical variables.
# Out:
# year                               2002.00
# house_price_index                    42.35
# personal_disposable_income           46.25
# real_house_price_index               68.50
# real_personal_disposable_income      75.69
# affordability_proxy                  93.11
# country_encoded                      13.00
# iso_encoded                          12.00
# dtype: float64

# %%
df.hist(figsize=(15,10))

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.boxplot(y=df["house_price_index"])

plt.title("House Price Index")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.boxplot(
    y=df["personal_disposable_income"]
)

plt.title("Personal Disposable Income")

plt.show()

# %%
numeric_df = df.select_dtypes(include=np.number)

plt.figure(figsize=(10,8))

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Matrix")

plt.show()

# %%
sns.pairplot(
    df[
        [
            "house_price_index",
            "personal_disposable_income",
            "real_house_price_index",
            "affordability_proxy"
        ]
    ]
)

plt.show()

# %%
df.skew(numeric_only=True)
# Out:
# year                              -0.089093
# house_price_index                  0.377290
# personal_disposable_income         0.141967
# real_house_price_index             0.130441
# real_personal_disposable_income   -0.228811
# affordability_proxy                0.060736
# country_encoded                   -0.003034
# iso_encoded                       -0.005634
# dtype: float64

# %%
plt.figure(figsize=(10,5))

sns.lineplot(
    x="year",
    y="house_price_index",
    data=df
)

plt.title("House Price Index Over Time")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    x="personal_disposable_income",
    y="house_price_index",
    data=df
)

plt.show()

# %% [markdown]
# Anomaly Detection
#
# Boxplots revealed a few extreme observations in housing prices and disposable income. These outliers may represent countries or years with unusually high economic indicators.

# %% [markdown]
# Inference 1:
# House prices generally increase with disposable income.
#
# Inference 2:
# Real house price index is strongly associated with house price index.
#
# Inference 3:
# Some observations exhibit unusually high values and are treated as outliers.
#
# Inference 4:
# Affordability differs across countries and years.
#
# Inference 5:
# Income-related variables show positive correlation with housing indicators.

# %% [markdown]
# Conclusion
#
# 1. Summary statistics were generated.
# 2. Histograms were used to understand distributions.
# 3. Boxplots were used for anomaly detection.
# 4. Correlation matrix revealed feature relationships.
# 5. Pairplots visualized interactions among variables.
# 6. Trends were identified using line plots.
# 7. Feature-level inferences were derived successfully.
#
# The dataset demonstrates meaningful relationships between housing prices and income-related variables.
